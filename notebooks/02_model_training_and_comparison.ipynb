# %% [markdown]
# # 02 Model Training And Comparison
#
# Use this notebook to train and compare the two selected models:
#
# - `DecisionTreeClassifier`
# - `RandomForestClassifier`
#
# Start by reusing the final train/test split logic from `01_data_preparation.ipynb`.
